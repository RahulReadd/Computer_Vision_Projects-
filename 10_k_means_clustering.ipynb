# %% [markdown]
# <a href="https://colab.research.google.com/github/RahulReadd/Computer_Vision_Projects-/blob/main/10_k_means_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Mall_Customers.csv')
X = dataset.iloc[:, [3, 4]].values ## Annual income and spending score are selected

# %% [markdown]
# ## Using the elbow method to find the optimal number of clusters

# %%
from sklearn.cluster import KMeans
WCSS = []
for i in range(1, 11): 
  Kmeans = KMeans(n_clusters= i,  init = 'k-means++' , random_state = 42 )
  Kmeans.fit(X)
  WCSS.append(Kmeans.inertia_)

plt.plot(range(1,11), WCSS)
plt.title("The elbow method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Training the K-Means model on the dataset

# %%
Kmeans = KMeans(n_clusters= 5,  init = 'k-means++' , random_state = 42 )
y_Kmeans = Kmeans.fit_predict(X)

# %% [markdown]
# ## Visualising the clusters

# %%
plt.scatter(x = X[y_Kmeans ==0, 0], y = X[y_Kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster_1')
plt.scatter(x = X[y_Kmeans ==1, 0], y = X[y_Kmeans == 1, 1], s = 100, c = 'green', label = 'Cluster_2')
plt.scatter(x = X[y_Kmeans ==2, 0], y = X[y_Kmeans == 2, 1], s = 100, c = 'blue', label = 'Cluster_3')
plt.scatter(x = X[y_Kmeans ==3, 0], y = X[y_Kmeans == 3, 1], s = 100, c = 'yellow', label = 'Cluster_4')
plt.scatter(x = X[y_Kmeans ==4, 0], y = X[y_Kmeans == 4, 1], s = 100, c = 'pink', label = 'Cluster_5')
plt.title('Customer Cluster based on income and spending')
plt.xlabel('Annual_Income')
plt.ylabel('Spending_Score')
plt.legend()
plt.show()
